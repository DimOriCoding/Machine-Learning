# %%
# 1st exercise-Face recognition by using  the Eigenfaces method, which is the combination of Principal Component Analysis (PCA) algorithm and of the K nearest
# neighbour (K = 1) with the euclidean distance as a metric
! pip install opencv-contrib-python
! pip install scikit-image
! pip install scikit-learn
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: opencv-contrib-python in /usr/local/lib/python3.10/dist-packages (4.7.0.72)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.10/dist-packages (from opencv-contrib-python) (1.22.4)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.10/dist-packages (0.19.3)
# Requirement already satisfied: numpy>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image) (1.22.4)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image) (1.10.1)
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.10/dist-packages (from scikit-image) (3.1)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,!=8.3.0,>=6.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image) (8.4.0)
# Requirement already satisfied: imageio>=2.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image) (2.25.1)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.10/dist-packages (from scikit-image) (2023.4.12)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image) (1.4.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image) (23.1)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (1.2.2)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.22.4)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.10.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (3.1.0)

# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !unzip /content/gdrive/MyDrive/faces.zip
# Out:
# Archive:  /content/gdrive/MyDrive/faces.zip
#  extracting: faces/person02_19.png
#  extracting: faces/person02_20.png
#  extracting: faces/person02_21.png
#  extracting: faces/person02_22.png
#  extracting: faces/person02_23.png
#  extracting: faces/person02_24.png
#  extracting: faces/person02_25.png
#  extracting: faces/person02_26.png
#  extracting: faces/person02_27.png
#  extracting: faces/person02_28.png
#  extracting: faces/person02_29.png
#  extracting: faces/person02_30.png
#  extracting: faces/person02_31.png
#  extracting: faces/person02_32.png
#  extracting: faces/person02_33.png
#  extracting: faces/person02_34.png
#  extracting: faces/person02_35.png
#  extracting: faces/person02_36.png
#  extracting: faces/person02_37.png
#  extracting: faces/person02_38.png
#  extracting: faces/person02_39.png
#  extracting: faces/person02_40.png
#  extracting: faces/person02_41.png
#  extracting: faces/person02_42.png
#  extracting: faces/person02_43.png
#  extracting: faces/person02_44.png
#  extracting: faces/person02_45.png
#  extracting: faces/person02_46.png
#  extracting: faces/person02_47.png
#  extracting: faces/person02_48.png
#  extracting: faces/person02_49.png
#  extracting: faces/person02_50.png
#  extracting: faces/person02_51.png
#  extracting: faces/person02_52.png
#  extracting: faces/person02_53.png
#  extracting: faces/person02_54.png
#  extracting: faces/person02_55.png
#  extracting: faces/person02_56.png
#  extracting: faces/person02_57.png
#  extracting: faces/person02_58.png
#  extracting: faces/person02_59.png
#  extracting: faces/person02_60.png
#  extracting: faces/person02_61.png
#  extracting: faces/person02_62.png
#  extracting: faces/person02_63.png
#  extracting: faces/person02_64.png
#  extracting: faces/person03_01.png
#  extracting: faces/person03_02.png
#  extracting: faces/person03_03.png
#  extracting: faces/person03_04.png
#  extracting: faces/person03_05.png
#  extracting: faces/person03_06.png
#  extracting: faces/person03_07.png
#  extracting: faces/person03_08.png
#  extracting: faces/person03_09.png
#  extracting: faces/person03_10.png
#  extracting: faces/person03_11.png
#  extracting: faces/person03_12.png
#  extracting: faces/person03_13.png
#  extracting: faces/person03_14.png
#  extracting: faces/person03_15.png
#  extracting: faces/person03_16.png
#  extracting: faces/person03_17.png
#  extracting: faces/person03_18.png
#  extracting: faces/person03_19.png
#  extracting: faces/person03_20.png
#  extracting: faces/person03_21.png
#  extracting: faces/person03_22.png
#  extracting: faces/person03_23.png
#  extracting: faces/person03_24.png
#  extracting: faces/person03_25.png
#  extracting: faces/person03_26.png
#  extracting: faces/person03_27.png
#  extracting: faces/person03_28.png
#  extracting: faces/person03_29.png
#  extracting: faces/person03_30.png
#  extracting: faces/person03_31.png
#  extracting: faces/person03_32.png
#  extracting: faces/person03_33.png
#  extracting: faces/person03_34.png
#  extracting: faces/person03_35.png
#  extracting: faces/person03_36.png
#  extracting: faces/person03_37.png
#  extracting: faces/person03_38.png
#  extracting: faces/person03_39.png
#  extracting: faces/person03_40.png
#  extracting: faces/person03_41.png
#  extracting: faces/person03_42.png
#  extracting: faces/person03_43.png
#  extracting: faces/person03_44.png
#  extracting: faces/person03_45.png
#  extracting: faces/person03_46.png
#  extracting: faces/person03_47.png
#  extracting: faces/person03_48.png
#  extracting: faces/person03_49.png
#  extracting: faces/person03_50.png
#  extracting: faces/person03_51.png
#  extracting: faces/person03_52.png
#  extracting: faces/person03_53.png
#  extracting: faces/person03_54.png
#  extracting: faces/person03_55.png
#  extracting: faces/person03_56.png
#  extracting: faces/person03_57.png
#  extracting: faces/person03_58.png
#  extracting: faces/person03_59.png
#  extracting: faces/person03_60.png
#  extracting: faces/person03_61.png
#  extracting: faces/person03_62.png
#  extracting: faces/person03_63.png
#  extracting: faces/person03_64.png
#  extracting: faces/person04_01.png
#  extracting: faces/person04_02.png
#  extracting: faces/person04_03.png
#  extracting: faces/person04_04.png
#  extracting: faces/person04_05.png
#  extracting: faces/person04_06.png
#  extracting: faces/person04_07.png
#  extracting: faces/person04_08.png
#  extracting: faces/person04_09.png
#  extracting: faces/person04_10.png
#  extracting: faces/person04_11.png
#  extracting: faces/person04_12.png
#  extracting: faces/person04_13.png
#  extracting: faces/person04_14.png
#  extracting: faces/person04_15.png
#  extracting: faces/person04_16.png
#  extracting: faces/person04_17.png
#  extracting: faces/person04_18.png
#  extracting: faces/person04_19.png
#  extracting: faces/person04_20.png
#  extracting: faces/person04_21.png
#  extracting: faces/person04_22.png
#  extracting: faces/person04_23.png
#  extracting: faces/person04_24.png
#  extracting: faces/person04_25.png
#  extracting: faces/person04_26.png
#  extracting: faces/person04_27.png
#  extracting: faces/person04_28.png
#  extracting: faces/person04_29.png
#  extracting: faces/person04_30.png
#  extracting: faces/person04_31.png
#  extracting: faces/person04_32.png
#  extracting: faces/person04_33.png
#  extracting: faces/person04_34.png
#  extracting: faces/person04_35.png
#  extracting: faces/person04_36.png
#  extracting: faces/person04_37.png
#  extracting: faces/person04_38.png
#  extracting: faces/person04_39.png
#  extracting: faces/person04_40.png
#  extracting: faces/person04_41.png
#  extracting: faces/person04_42.png
#  extracting: faces/person04_43.png
#  extracting: faces/person04_44.png
#  extracting: faces/person04_45.png
#  extracting: faces/person04_46.png
#  extracting: faces/person04_47.png
#  extracting: faces/person04_48.png
#  extracting: faces/person04_49.png
#  extracting: faces/person04_50.png
#  extracting: faces/person04_51.png
#  extracting: faces/person04_52.png
#  extracting: faces/person04_54.png
#  extracting: faces/person04_55.png
#  extracting: faces/person07_35.png
#  extracting: faces/person07_36.png
#  extracting: faces/person07_37.png
#  extracting: faces/person07_38.png
#  extracting: faces/person07_39.png
#  extracting: faces/person07_40.png
#  extracting: faces/person07_41.png
#  extracting: faces/person07_42.png
#  extracting: faces/person07_43.png
#  extracting: faces/person07_44.png
#  extracting: faces/person07_45.png
#  extracting: faces/person07_46.png
#  extracting: faces/person07_47.png
#  extracting: faces/person07_48.png
#  extracting: faces/person07_49.png
#  extracting: faces/person07_50.png
#  extracting: faces/person07_51.png
#  extracting: faces/person07_52.png
#  extracting: faces/person07_53.png
#  extracting: faces/person07_54.png
#  extracting: faces/person07_55.png
#  extracting: faces/person07_56.png
#  extracting: faces/person07_57.png
#  extracting: faces/person07_58.png
#  extracting: faces/person07_59.png
#  extracting: faces/person07_60.png
#  extracting: faces/person07_61.png
#  extracting: faces/person07_62.png
#  extracting: faces/person07_63.png
#  extracting: faces/person07_64.png
#  extracting: faces/person08_01.png
#  extracting: faces/person08_02.png
#  extracting: faces/person08_03.png
#  extracting: faces/person08_04.png
#  extracting: faces/person08_05.png
#  extracting: faces/person08_06.png
#  extracting: faces/person08_07.png
#  extracting: faces/person08_08.png
#  extracting: faces/person08_09.png
#  extracting: faces/person08_10.png
#  extracting: faces/person08_11.png
#  extracting: faces/person08_12.png
#  extracting: faces/person08_13.png
#  extracting: faces/person08_14.png
#  extracting: faces/person08_15.png
#  extracting: faces/person08_16.png
#  extracting: faces/person08_17.png
#  extracting: faces/person08_18.png
#  extracting: faces/person08_19.png
#  extracting: faces/person08_20.png
#  extracting: faces/person08_21.png
#  extracting: faces/person08_22.png
#  extracting: faces/person08_23.png
#  extracting: faces/person08_24.png
#  extracting: faces/person08_25.png
#  extracting: faces/person08_26.png
#  extracting: faces/person08_27.png
#  extracting: faces/person08_28.png
#  extracting: faces/person08_29.png
#  extracting: faces/person08_30.png
#  extracting: faces/person08_31.png
#  extracting: faces/person08_32.png
#  extracting: faces/person08_33.png
#  extracting: faces/person08_34.png
#  extracting: faces/person08_35.png
#  extracting: faces/person08_36.png
#  extracting: faces/person08_37.png
#  extracting: faces/person08_38.png
#  extracting: faces/person08_39.png
#  extracting: faces/person08_40.png
#  extracting: faces/person08_41.png
#  extracting: faces/person08_42.png
#  extracting: faces/person08_43.png
#  extracting: faces/person08_44.png
#  extracting: faces/person08_45.png
#  extracting: faces/person08_46.png
#  extracting: faces/person08_47.png
#  extracting: faces/person08_48.png
#  extracting: faces/person08_49.png
#  extracting: faces/person08_50.png
#  extracting: faces/person08_51.png
#  extracting: faces/person08_52.png
#  extracting: faces/person08_53.png
#  extracting: faces/person08_54.png
#  extracting: faces/person08_55.png
#  extracting: faces/person08_56.png
#  extracting: faces/person08_57.png
#  extracting: faces/person08_58.png
#  extracting: faces/person08_59.png
#  extracting: faces/person08_60.png
#  extracting: faces/person08_61.png
#  extracting: faces/person08_62.png
#  extracting: faces/person08_63.png
#  extracting: faces/person08_64.png
#  extracting: faces/person09_01.png
#  extracting: faces/person09_02.png
#  extracting: faces/person09_03.png
#  extracting: faces/person09_04.png
#  extracting: faces/person09_05.png
#  extracting: faces/person09_06.png
#  extracting: faces/person09_07.png
#  extracting: faces/person09_08.png
#  extracting: faces/person09_09.png
#  extracting: faces/person09_10.png
#  extracting: faces/person09_11.png
#  extracting: faces/person09_12.png
#  extracting: faces/person09_13.png
#  extracting: faces/person09_14.png
#  extracting: faces/person09_15.png
#  extracting: faces/person09_16.png
#  extracting: faces/person09_17.png
#  extracting: faces/person09_18.png
#  extracting: faces/person09_19.png
#  extracting: faces/person09_20.png
#  extracting: faces/person09_21.png
#  extracting: faces/person09_22.png
#  extracting: faces/person09_23.png
#  extracting: faces/person09_24.png
#  extracting: faces/person09_25.png
#  extracting: faces/person09_26.png
#  extracting: faces/person09_27.png
#  extracting: faces/person09_28.png
#  extracting: faces/person09_29.png
#  extracting: faces/person09_30.png
#  extracting: faces/person09_31.png
#  extracting: faces/person09_32.png
#  extracting: faces/person09_33.png
#  extracting: faces/person09_34.png
#  extracting: faces/person09_35.png
#  extracting: faces/person09_36.png
#  extracting: faces/person09_37.png
#  extracting: faces/person09_38.png
#  extracting: faces/person09_39.png
#  extracting: faces/person09_40.png
#  extracting: faces/person09_41.png
#  extracting: faces/person09_42.png
#  extracting: faces/person09_43.png
#  extracting: faces/person09_44.png
#  extracting: faces/person09_45.png
#  extracting: faces/person09_46.png
#  extracting: faces/person09_47.png
#  extracting: faces/person09_48.png
#  extracting: faces/person09_49.png
#  extracting: faces/person09_50.png
#  extracting: faces/person09_51.png
#  extracting: faces/person09_52.png
#  extracting: faces/person09_53.png
#  extracting: faces/person09_54.png
#  extracting: faces/person09_55.png
#  extracting: faces/person09_56.png
#  extracting: faces/person09_57.png
#  extracting: faces/person09_58.png
#  extracting: faces/person09_59.png
#  extracting: faces/person09_60.png
#  extracting: faces/person09_61.png
#  extracting: faces/person09_62.png
#  extracting: faces/person09_63.png
#  extracting: faces/person09_64.png
#  extracting: faces/person10_01.png
#  extracting: faces/person10_02.png
#  extracting: faces/person10_03.png
#  extracting: faces/person10_04.png
#  extracting: faces/person10_05.png
#  extracting: faces/person10_06.png
#  extracting: faces/person10_07.png
#  extracting: faces/person10_08.png
#  extracting: faces/person10_09.png
#  extracting: faces/person10_10.png
#  extracting: faces/person10_11.png
#  extracting: faces/person10_12.png
#  extracting: faces/person10_13.png
#  extracting: faces/person10_14.png
#  extracting: faces/person10_15.png
#  extracting: faces/person10_16.png
#  extracting: faces/person10_17.png
#  extracting: faces/person10_18.png
#  extracting: faces/person10_19.png
#  extracting: faces/person10_20.png
#  extracting: faces/person10_21.png
#  extracting: faces/person10_22.png
#  extracting: faces/person10_23.png
#  extracting: faces/person10_24.png
#  extracting: faces/person10_25.png
#  extracting: faces/person10_26.png
#  extracting: faces/person10_27.png
#  extracting: faces/person10_28.png
#  extracting: faces/person10_29.png
#  extracting: faces/person10_30.png
#  extracting: faces/person10_31.png
#  extracting: faces/person10_32.png
#  extracting: faces/person10_33.png
#  extracting: faces/person10_34.png
#  extracting: faces/person10_35.png
#  extracting: faces/person10_36.png
#  extracting: faces/person10_37.png
#  extracting: faces/person10_38.png
#  extracting: faces/person10_39.png
#  extracting: faces/person10_40.png
#  extracting: faces/person10_41.png
#  extracting: faces/person10_42.png
#  extracting: faces/person10_43.png
#  extracting: faces/person10_44.png
#  extracting: faces/person10_45.png
#  extracting: faces/person10_46.png
#  extracting: faces/person10_47.png
#  extracting: faces/person10_48.png
#  extracting: faces/person10_49.png
#  extracting: faces/person10_50.png
#  extracting: faces/person10_51.png
#  extracting: faces/person10_52.png
#  extracting: faces/person10_53.png
#  extracting: faces/person10_54.png
#  extracting: faces/person10_55.png
#  extracting: faces/person10_56.png
#  extracting: faces/person10_57.png
#  extracting: faces/person10_58.png
#  extracting: faces/person10_59.png
#  extracting: faces/person10_60.png
#  extracting: faces/person10_61.png
#  extracting: faces/person10_62.png
#  extracting: faces/person10_63.png
#  extracting: faces/person10_64.png
#  extracting: faces/person04_53.png
#  extracting: faces/person01_01.png
#  extracting: faces/person01_02.png
#  extracting: faces/person01_03.png
#  extracting: faces/person01_04.png
#  extracting: faces/person01_05.png
#  extracting: faces/person01_06.png
#  extracting: faces/person01_07.png
#  extracting: faces/person01_08.png
#  extracting: faces/person01_09.png
#  extracting: faces/person01_10.png
#  extracting: faces/person01_11.png
#  extracting: faces/person01_12.png
#  extracting: faces/person01_13.png
#  extracting: faces/person01_14.png
#  extracting: faces/person01_15.png
#  extracting: faces/person01_16.png
#  extracting: faces/person01_17.png
#  extracting: faces/person01_18.png
#  extracting: faces/person01_19.png
#  extracting: faces/person01_20.png
#  extracting: faces/person01_21.png
#  extracting: faces/person01_22.png
#  extracting: faces/person01_23.png
#  extracting: faces/person01_24.png
#  extracting: faces/person01_25.png
#  extracting: faces/person01_26.png
#  extracting: faces/person01_27.png
#  extracting: faces/person01_28.png
#  extracting: faces/person01_29.png
#  extracting: faces/person01_30.png
#  extracting: faces/person01_31.png
#  extracting: faces/person01_32.png
#  extracting: faces/person01_33.png
#  extracting: faces/person01_34.png
#  extracting: faces/person01_35.png
#  extracting: faces/person01_36.png
#  extracting: faces/person01_37.png
#  extracting: faces/person01_38.png
#  extracting: faces/person01_39.png
#  extracting: faces/person01_40.png
#  extracting: faces/person01_41.png
#  extracting: faces/person01_42.png
#  extracting: faces/person01_43.png
#  extracting: faces/person01_44.png
#  extracting: faces/person01_45.png
#  extracting: faces/person01_46.png
#  extracting: faces/person01_47.png
#  extracting: faces/person01_48.png
#  extracting: faces/person01_49.png
#  extracting: faces/person01_50.png
#  extracting: faces/person01_51.png
#  extracting: faces/person01_52.png
#  extracting: faces/person01_53.png
#  extracting: faces/person01_54.png
#  extracting: faces/person01_55.png
#  extracting: faces/person01_56.png
#  extracting: faces/person01_57.png
#  extracting: faces/person01_58.png
#  extracting: faces/person01_59.png
#  extracting: faces/person01_60.png
#  extracting: faces/person01_61.png
#  extracting: faces/person01_62.png
#  extracting: faces/person01_63.png
#  extracting: faces/person01_64.png
#  extracting: faces/person02_01.png
#  extracting: faces/person02_02.png
#  extracting: faces/person02_03.png
#  extracting: faces/person02_04.png
#  extracting: faces/person02_05.png
#  extracting: faces/person02_06.png
#  extracting: faces/person02_07.png
#  extracting: faces/person02_08.png
#  extracting: faces/person02_09.png
#  extracting: faces/person02_10.png
#  extracting: faces/person02_11.png
#  extracting: faces/person02_12.png
#  extracting: faces/person02_13.png
#  extracting: faces/person02_14.png
#  extracting: faces/person02_15.png
#  extracting: faces/person02_16.png
#  extracting: faces/person02_17.png
#  extracting: faces/person02_18.png
#  extracting: faces/person04_56.png
#  extracting: faces/person04_57.png
#  extracting: faces/person04_58.png
#  extracting: faces/person04_59.png
#  extracting: faces/person04_60.png
#  extracting: faces/person04_61.png
#  extracting: faces/person04_62.png
#  extracting: faces/person04_63.png
#  extracting: faces/person04_64.png
#  extracting: faces/person05_01.png
#  extracting: faces/person05_02.png
#  extracting: faces/person05_03.png
#  extracting: faces/person05_04.png
#  extracting: faces/person05_05.png
#  extracting: faces/person05_06.png
#  extracting: faces/person05_07.png
#  extracting: faces/person05_08.png
#  extracting: faces/person05_09.png
#  extracting: faces/person05_10.png
#  extracting: faces/person05_11.png
#  extracting: faces/person05_12.png
#  extracting: faces/person05_13.png
#  extracting: faces/person05_14.png
#  extracting: faces/person05_15.png
#  extracting: faces/person05_16.png
#  extracting: faces/person05_17.png
#  extracting: faces/person05_18.png
#  extracting: faces/person05_19.png
#  extracting: faces/person05_20.png
#  extracting: faces/person05_21.png
#  extracting: faces/person05_22.png
#  extracting: faces/person05_23.png
#  extracting: faces/person05_24.png
#  extracting: faces/person05_25.png
#  extracting: faces/person05_26.png
#  extracting: faces/person05_27.png
#  extracting: faces/person05_28.png
#  extracting: faces/person05_29.png
#  extracting: faces/person05_30.png
#  extracting: faces/person05_31.png
#  extracting: faces/person05_32.png
#  extracting: faces/person05_33.png
#  extracting: faces/person05_34.png
#  extracting: faces/person05_35.png
#  extracting: faces/person05_36.png
#  extracting: faces/person05_37.png
#  extracting: faces/person05_38.png
#  extracting: faces/person05_39.png
#  extracting: faces/person05_40.png
#  extracting: faces/person05_41.png
#  extracting: faces/person05_42.png
#  extracting: faces/person05_43.png
#  extracting: faces/person05_44.png
#  extracting: faces/person05_45.png
#  extracting: faces/person05_46.png
#  extracting: faces/person05_47.png
#  extracting: faces/person05_48.png
#  extracting: faces/person05_49.png
#  extracting: faces/person05_50.png
#  extracting: faces/person05_51.png
#  extracting: faces/person05_52.png
#  extracting: faces/person05_53.png
#  extracting: faces/person05_54.png
#  extracting: faces/person05_55.png
#  extracting: faces/person05_56.png
#  extracting: faces/person05_57.png
#  extracting: faces/person05_58.png
#  extracting: faces/person05_59.png
#  extracting: faces/person05_60.png
#  extracting: faces/person05_61.png
#  extracting: faces/person05_62.png
#  extracting: faces/person05_63.png
#  extracting: faces/person05_64.png
#  extracting: faces/person06_01.png
#  extracting: faces/person06_02.png
#  extracting: faces/person06_03.png
#  extracting: faces/person06_04.png
#  extracting: faces/person06_05.png
#  extracting: faces/person06_06.png
#  extracting: faces/person06_07.png
#  extracting: faces/person06_08.png
#  extracting: faces/person06_09.png
#  extracting: faces/person06_10.png
#  extracting: faces/person06_11.png
#  extracting: faces/person06_12.png
#  extracting: faces/person06_13.png
#  extracting: faces/person06_14.png
#  extracting: faces/person06_15.png
#  extracting: faces/person06_16.png
#  extracting: faces/person06_17.png
#  extracting: faces/person06_18.png
#  extracting: faces/person06_19.png
#  extracting: faces/person06_20.png
#  extracting: faces/person06_21.png
#  extracting: faces/person06_22.png
#  extracting: faces/person06_23.png
#  extracting: faces/person06_24.png
#  extracting: faces/person06_25.png
#  extracting: faces/person06_26.png
#  extracting: faces/person06_27.png
#  extracting: faces/person06_28.png
#  extracting: faces/person06_29.png
#  extracting: faces/person06_30.png
#  extracting: faces/person06_31.png
#  extracting: faces/person06_32.png
#  extracting: faces/person06_33.png
#  extracting: faces/person06_34.png
#  extracting: faces/person06_35.png
#  extracting: faces/person06_36.png
#  extracting: faces/person06_37.png
#  extracting: faces/person06_38.png
#  extracting: faces/person06_39.png
#  extracting: faces/person06_40.png
#  extracting: faces/person06_41.png
#  extracting: faces/person06_42.png
#  extracting: faces/person06_43.png
#  extracting: faces/person06_44.png
#  extracting: faces/person06_45.png
#  extracting: faces/person06_46.png
#  extracting: faces/person06_47.png
#  extracting: faces/person06_48.png
#  extracting: faces/person06_49.png
#  extracting: faces/person06_50.png
#  extracting: faces/person06_51.png
#  extracting: faces/person06_52.png
#  extracting: faces/person06_53.png
#  extracting: faces/person06_54.png
#  extracting: faces/person06_55.png
#  extracting: faces/person06_56.png
#  extracting: faces/person06_57.png
#  extracting: faces/person06_58.png
#  extracting: faces/person06_59.png
#  extracting: faces/person06_60.png
#  extracting: faces/person06_61.png
#  extracting: faces/person06_62.png
#  extracting: faces/person06_63.png
#  extracting: faces/person06_64.png
#  extracting: faces/person07_01.png
#  extracting: faces/person07_02.png
#  extracting: faces/person07_03.png
#  extracting: faces/person07_04.png
#  extracting: faces/person07_05.png
#  extracting: faces/person07_06.png
#  extracting: faces/person07_07.png
#  extracting: faces/person07_08.png
#  extracting: faces/person07_09.png
#  extracting: faces/person07_10.png
#  extracting: faces/person07_11.png
#  extracting: faces/person07_12.png
#  extracting: faces/person07_13.png
#  extracting: faces/person07_14.png
#  extracting: faces/person07_15.png
#  extracting: faces/person07_16.png
#  extracting: faces/person07_17.png
#  extracting: faces/person07_18.png
#  extracting: faces/person07_19.png
#  extracting: faces/person07_20.png
#  extracting: faces/person07_21.png
#  extracting: faces/person07_22.png
#  extracting: faces/person07_23.png
#  extracting: faces/person07_24.png
#  extracting: faces/person07_25.png
#  extracting: faces/person07_26.png
#  extracting: faces/person07_27.png
#  extracting: faces/person07_28.png
#  extracting: faces/person07_29.png
#  extracting: faces/person07_30.png
#  extracting: faces/person07_31.png
#  extracting: faces/person07_32.png
#  extracting: faces/person07_33.png
#  extracting: faces/person07_34.png

# %%
from imutils import paths
import numpy as np
import cv2
import os
from statistics import stdev
def loadImages(path, set_number):
 imagePaths = list(paths.list_images(path))
 imagePaths.sort() #The image dataset is sorted in order to have an easier work
 #by acessing images of person 1 later images of person 2 etc.
 labels = []
 data = []
 if (set_number == "Set_1"):
      k = 0
      n = 7
 elif (set_number == "Set_2"):
      k = 7
      n = 19
 elif (set_number == "Set_3"):
      k = 19
      n = 31
 elif (set_number == "Set_4"):
      k = 31
      n = 45
 elif (set_number == "Set_5"):
      k = 45
      n = 64
 for image in range(len(imagePaths)):
   names = [image.split(os.path.sep)[-1] for image in imagePaths]
   person = names[image].split('_')[0]
   if (person == "person01"):
     labels.append(1)
   elif (person == "person02"):
     labels.append(2)
   elif (person == "person03"):
     labels.append(3)
   elif (person == "person04"):
     labels.append(4)
   elif (person == "person05"):
     labels.append(5)
   elif (person == "person06"):
     labels.append(6)
   elif (person == "person07"):
     labels.append(7)
   elif (person == "person08"):
     labels.append(8)
   elif (person == "person09"):
     labels.append(9)
   elif (person == "person10"):
     labels.append(10)
 #In order to have data for all people from the image dataset
 Labels = []
 while(n <= 640):
  for s in range(k,n):
   img = cv2.imread(imagePaths[s] , cv2.IMREAD_GRAYSCALE)
   img = img.reshape(-1)
   mean = np.mean(img)
   st_dev = np.std(img,ddof=1)
   img = (img-mean)/st_dev

   data.append(img)
   Labels.append(labels[s])
  k+= 64
  n+= 64
 data = np.asarray(data)
 #labels = np.unique(labels)

 return data, Labels


Set_1, labels_1 = loadImages("/content/faces", "Set_1")
Set_2, labels_2 = loadImages("/content/faces", "Set_2")
Set_3, labels_3 = loadImages("/content/faces", "Set_3")
Set_4, labels_4 = loadImages("/content/faces", "Set_4")
Set_5, labels_5 = loadImages("/content/faces", "Set_5")
print(len(Set_1),len(Set_2),len(Set_3),len(Set_4),len(Set_5))
# Out:
# 70 120 120 140 190

# %% [markdown]
# **Training with the Eigenfaces method, face recognition in all sets of the Yale B dataset, and image representation of the 9 main eigenvectors.**

# %%
from sklearn.decomposition import PCA
from sklearn.metrics import accuracy_score, classification_report
import matplotlib.pyplot as plt
import time
def plot_images(images, d, h, w):
 fig = plt.figure(figsize=(h, w))
 for i in range(len(images)):
    ax = fig.add_subplot(1, len(images), i + 1, xticks=[], yticks=[])
    ax.imshow(images[i].reshape(d,d),cmap=plt.cm.gray)
#Implement PCA algorithm for 9 components
pca_9 = PCA(n_components=9)
start = time.time()
X_train_pca_9 = pca_9.fit_transform(Set_1)
Xtest_1_pca9 = pca_9.transform(Set_1)
Xtest_2_pca9 = pca_9.transform(Set_2)
Xtest_3_pca9 = pca_9.transform(Set_3)
Xtest_4_pca9 = pca_9.transform(Set_4)
Xtest_5_pca9 = pca_9.transform(Set_5)
end = time.time()
print("[INFO] computing eigenfaces took {:.4f} seconds".format(
	end - start))


#KNN classifier for d = 9 principal components
from sklearn.neighbors import KNeighborsClassifier
clf_9 = KNeighborsClassifier(n_neighbors = 1)
clf_9.fit(X_train_pca_9, labels_1)
set19_prediction = clf_9.predict(Xtest_1_pca9)
set29_prediction = clf_9.predict(Xtest_2_pca9)
set39_prediction = clf_9.predict(Xtest_3_pca9)
set49_prediction = clf_9.predict(Xtest_4_pca9)
set59_prediction = clf_9.predict(Xtest_5_pca9)

print("Set_1 accuracy= ",accuracy_score(labels_1, set19_prediction))
print("Set_2 accuracy= ",accuracy_score(labels_2, set29_prediction))
print("Set_3 accuracy= ",accuracy_score(labels_3, set39_prediction))
print("Set_4 accuracy= ",accuracy_score(labels_4, set49_prediction))
print("Set_5 accuracy= ",accuracy_score(labels_5, set59_prediction))
plot_images(pca_9.components_, 50, 12, 12)
# Out:
# [INFO] computing eigenfaces took 0.1111 seconds
# Set_1 accuracy=  1.0
# Set_2 accuracy=  1.0
# Set_3 accuracy=  0.775
# Set_4 accuracy=  0.3357142857142857
# Set_5 accuracy=  0.14210526315789473

# %%
#Implement PCA algorithm for 30 components
pca_30 = PCA(n_components=30)
start = time.time()
X_train_pca_30 = pca_30.fit_transform(Set_1)
Xtest_1_pca30 = pca_30.transform(Set_1)
Xtest_2_pca30 = pca_30.transform(Set_2)
Xtest_3_pca30 = pca_30.transform(Set_3)
Xtest_4_pca30 = pca_30.transform(Set_4)
Xtest_5_pca30 = pca_30.transform(Set_5)
end = time.time()
print("[INFO] computing eigenfaces took {:.4f} seconds".format(
	end - start))
print(pca_30.components_.shape)
#KNN classifier for d = 30 principal components
from sklearn.neighbors import KNeighborsClassifier
clf_30 = KNeighborsClassifier(n_neighbors = 1)
clf_30.fit(X_train_pca_30, labels_1)
set130_prediction = clf_30.predict(Xtest_1_pca30)
set230_prediction = clf_30.predict(Xtest_2_pca30)
set330_prediction = clf_30.predict(Xtest_3_pca30)
set430_prediction = clf_30.predict(Xtest_4_pca30)
set530_prediction = clf_30.predict(Xtest_5_pca30)

print("Set_1 accuracy= ",accuracy_score(labels_1, set130_prediction))
print("Set_2 accuracy= ",accuracy_score(labels_2, set230_prediction))
print("Set_3 accuracy= ",accuracy_score(labels_3, set330_prediction))
print("Set_4 accuracy= ",accuracy_score(labels_4, set430_prediction))
print("Set_5 accuracy= ",accuracy_score(labels_5, set530_prediction))
# Out:
# [INFO] computing eigenfaces took 0.0634 seconds
# (30, 2500)
# Set_1 accuracy=  1.0
# Set_2 accuracy=  1.0
# Set_3 accuracy=  0.9583333333333334
# Set_4 accuracy=  0.4357142857142857
# Set_5 accuracy=  0.22631578947368422

# %% [markdown]
# **When transformed into images, the different eigenvectors express the patterns of the different persons in the dataset. Essentially, during reconstruction, the final result will be a linear combination of these different eigenvectors, regardless of their number.**

# %% [markdown]
# **With the exception of Set_1, which shows 100% classification accuracy since it was used to train the Eigenfaces method, for Set_2 we have 100% classification accuracy for both component values (d = 9 and d = 30) 100% classification accuracy, while for Set_3 the classification accuracy is very good, but not ideal (100%). For Set_4 and Set_5, it can be seen that the classification accuracy for both 9 and 30 eigenvectors is particularly low, especially for Set_5. The classification accuracy is higher for d = 30 eigenfaces for each Set. In conclusion, it can be observed that the less bright the image is and the more darkness there is from Set to Set, the lower the classification accuracy becomes and, consequently, the images are not classified correctly.**

# %% [markdown]
#  **Reconstruction of a random image from each of the 5 sets, for values d = 9 and d = 30.**

# %%
#Image reconstruction with the use of inverse_transform from pca by sklearn library
#Also the content of inverse_transform is multiplied with the standard deviation and in this result of this multiplication
#the mean of the corresponding images that are going to be reconstructed is added in order to have the initial image.
import random
images = list(paths.list_images('/content/faces'))
images.sort()


im1 = random.choice(Set_1)
im2 = random.choice(Set_2)
im3 = random.choice(Set_3)
im4 = random.choice(Set_4)
im5 = random.choice(Set_5)
# 5 random pictures the Yale B dataset
images_for_show = []
images_for_show.append(im1)
images_for_show.append(im2)
images_for_show.append(im3)
images_for_show.append(im4)
images_for_show.append(im5)

images_reconstruct9 = []

images_reconstruct9.append((np.std(im1,ddof=1)*pca_9.inverse_transform(pca_9.transform(im1.reshape(1,-1))))+np.mean(im1))## ## Τranσform the data to the new axes system-
#Projections of the data on the principal axes

images_reconstruct9.append((np.std(im2, ddof=1)*pca_9.inverse_transform(pca_9.transform(im2.reshape(1,-1))))+np.mean(im2))

images_reconstruct9.append((np.std(im3, ddof=1)*pca_9.inverse_transform(pca_9.transform(im3.reshape(1,-1))))+np.mean(im3))

images_reconstruct9.append((np.std(im4,ddof=1)*pca_9.inverse_transform(pca_9.transform(im4.reshape(1,-1))))+np.mean(im4))

images_reconstruct9.append((np.std(im5,ddof=1)*pca_9.inverse_transform(pca_9.transform(im5.reshape(1,-1))))+np.mean(im5))

#Reconstruct images for d = 30 eigenvectors
images_reconstruct30 = []

images_reconstruct30.append((np.std(im1, ddof=1)*pca_30.inverse_transform(pca_30.transform(im1.reshape(1,-1))))+np.mean(im1))

images_reconstruct30.append((np.std(im2, ddof=1)*pca_30.inverse_transform(pca_30.transform(im2.reshape(1,-1))))+np.mean(im2))

images_reconstruct30.append((np.std(im3, ddof=1)*pca_30.inverse_transform(pca_30.transform(im3.reshape(1,-1))))+np.mean(im3))

images_reconstruct30.append((np.std(im4, ddof=1)*pca_30.inverse_transform(pca_30.transform(im4.reshape(1,-1))))+np.mean(im4))

images_reconstruct30.append((np.std(im5, ddof=1)*pca_30.inverse_transform(pca_30.transform(im5.reshape(1,-1))))+np.mean(im5))

#plot the initial 5 images one from each set and the reconstructed forms of these images

plot_images(images_for_show, 50, 12, 12)# Plotting the initial images
plot_images(images_reconstruct9, 50, 12, 12)# Plotting the reconstructed images from top 9 eigenvectors
plot_images(images_reconstruct30, 50, 12, 12)# Plotting the reconstructed images from top 30 eigenvectors

# %% [markdown]
# **The image reconstruction quality is very good for Set_1 and is the best of all the other sets in the YaleB dataset because there is less shadow around the face in the images in Set_1, so it looks better and the representation is closer to the real face. In Set_5, we have the worst reconstruction because there is more shadow than light in each image, making accurate representation increasingly difficult. Set_4 has a slightly better representation than Set_5, while Set_2 and Set_3, we have similar image reconstructions close to those of Set_1, with slightly better representations of the images in Set_2. Therefore, moving from set to set where more dark spots are observed, the characteristics of the reconstructed images will not be rendered as they should. It is observed that for d = 30, images with greater detail and closer to the actual image are obtained.**

# %% [markdown]
# **Application of the Singular Value Decomposition (SVD) algorithm to Set 1 of images from the Yale B dataset**

# %%
from numpy.linalg import svd
U, S, Vt = svd(Set_1)
print(U.shape, S.shape, Vt.shape)
#top 9 singular vectors
# The rows of V^T are the columns of V matrix
print (Vt[:9])
B = np.transpose(Vt)
plot_images(Vt[:9], 50, 15, 15)
plot_images(pca_9.components_, 50, 15, 15)# Plotting the top 9 principal components
# Out:
# (70, 70) (70,) (2500, 2500)
# [[ 0.03636842  0.03654541  0.03531635 ...  0.02084395  0.02787873
#    0.03249515]
#  [ 0.02822441  0.03018412  0.03626795 ... -0.00021871  0.00603449
#    0.00345427]
#  [-0.01817649 -0.01373492 -0.00922437 ...  0.03328254  0.03566883
#    0.03746064]
#  ...
#  [-0.02601027 -0.00501805 -0.00585701 ... -0.0180565  -0.02213445
#   -0.0372693 ]
#  [ 0.02181826  0.02555648  0.0446969  ...  0.00756061  0.01838046
#    0.02590742]
#  [ 0.00424789 -0.02927108 -0.03467177 ... -0.01381356 -0.01042823
#   -0.01137012]]

# %% [markdown]
# **From the above, it appears that for the 9 principal singular vectors, their representation is not the same as that of the 9 principal eigenvectors. This is to be expected because PCA and SVD are essentially different methods of matrix factorization.**
#
# **The main difference between them lies in the method used to calculate the eigenvectors. In the Principal Component Analysis (PCA) method, the covariance matrix Σ (or the scatter matrix, which is an estimate of the covariance matrix when calculating the covariance matrix is costly) of the input data must first be calculated, then find its eigenvalues and eigenvectors through matrix factorization (Σ =U*L*U^T, where L is the matrix of eigenvalues and U is the matrix of eigenvectors), always in symmetric and centered data.**
#
# **In contrast, in the Singular Value Decomposition (SVD) method, the same process is performed directly on the input data (matrix X) (X =U*S*V^T, where S is the matrix of eigenvalues and U,V are matrices whose columns are left and right eigenvectors). even on non-symmetric data (non-square matrices, for example).**

# %% [markdown]
# **Assignment 2: Image classification using the Support Vector Machine (SVM) algorithm**

# %%
# 2nd exercise-Classification of images by using Support Vector Machine (SVM) algorithm
import tensorflow
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import fetch_openml
import numpy as np
from keras.datasets import mnist

# %%
(train_X, train_y), (test_X, test_y) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step

# %%
print('X_train: ' +str(train_X.shape))
print('Y_train: ' +str(train_y.shape))
print('X_test:  '  +str(test_X.shape))
print('Y_test:  '  +str(test_y.shape))
# Out:
# X_train: (60000, 28, 28)
# Y_train: (60000,)
# X_test:  (10000, 28, 28)
# Y_test:  (10000,)

# %%
train_X = train_X.reshape(train_X.shape[0], 784)
test_X = test_X.reshape(test_X.shape[0], 784)

# %%
## Normalization

train_X = train_X/255.0
test_X = test_X/255.0
print("train data:", train_X.shape)
print("train data:", test_X.shape)
# Out:
# train data: (60000, 784)
# train data: (10000, 784)

# %%
#Linear Model buliding
import time
start = time.time()
svm_linear = SVC(kernel='linear', C = 1, gamma = 0.001)
svm_linear.fit(train_X, train_y)

# predict
y_pred_train= svm_linear.predict(train_X)
y_pred_linear = svm_linear.predict(test_X)
end = time.time()
print("done in % 0.3fs" % (end - start))
print("train accuracy:", accuracy_score(train_y, y_pred_train), "\n")
print("test accuracy:", accuracy_score(test_y, y_pred_linear), "\n")
print(classification_report(test_y, y_pred_linear))
# Out:
# done in  683.537s
# train accuracy: 0.97075
#
# test accuracy: 0.9404
#
#               precision    recall  f1-score   support
#
#            0       0.95      0.98      0.96       980
#            1       0.97      0.99      0.98      1135
#            2       0.93      0.94      0.93      1032
#            3       0.91      0.94      0.92      1010
#            4       0.94      0.96      0.95       982
#            5       0.91      0.90      0.91       892
#            6       0.96      0.95      0.95       958
#            7       0.95      0.93      0.94      1028
#            8       0.94      0.90      0.92       974
#            9       0.95      0.91      0.93      1009
#
#     accuracy                           0.94     10000
#    macro avg       0.94      0.94      0.94     10000
# weighted avg       0.94      0.94      0.94     10000

# %%
# Buliding of the non-linear model
# using rbf kernel
start = time.time()
# model
svm_non_linear = SVC(kernel='rbf', C = 10, gamma = 0.01)

# fit
svm_non_linear.fit(train_X, train_y)

# predict
y_pred_train= svm_non_linear.predict(train_X)
y_pred_non_linear = svm_non_linear.predict(test_X)
end = time.time()
print("done in % 0.3fs" % (end - start))
print("train accuracy:", accuracy_score(train_y, y_pred_train), "\n")
print("test accuracy:", accuracy_score(test_y, y_pred_non_linear), "\n")
print(classification_report(test_y, y_pred_non_linear))

# %% [markdown]
# **More specifically, for the SVM model with linear and rbf kernels, we used normalization constant values C, 1, and 10, as well as values for the gamma variable 0.01 and 0.001. The best performance in both the training set and the test set is for the rbf kernel type with values C = 10 and gamma = 0.01, with a classification accuracy for the training set equal to 0.99957 and an accuracy for the test set is 0.9833 in an execution time of 17 minutes and 15 seconds.**

# %% [markdown]
# **The Principal Component Analysis (PCA) algorithm will be applied to this task, using the C and γ values that gave the best results from the SVM algorithm. For the PCA algorithm, three values of the desired percentage of retained variance (essentially the number of components) will be used, and the SVM algorithm will be re-run with these values.**

# %%
#The values of the desired percentage of conservation variance are 0.50, 0.75 and 0.90
from sklearn.decomposition import PCA
import time
start = time.time()
pca = PCA(n_components = 0.9).fit(train_X)
X_train_pca = pca.transform(train_X)
X_test_pca = pca.transform(test_X)
# Using Svm model with rbf kernel, C=10, gamma = 0.01, which is the values that for this model the results are better than all other values of C and gamma.

# model
svm= SVC(kernel='rbf', C = 10, gamma = 0.01)

# fit
svm.fit(X_train_pca, train_y)

# predict
y_pred_pca = svm.predict(X_test_pca)
end = time.time()
print("done in % 0.3fs" % (end - start))
print("accuracy:", accuracy_score(test_y, y_pred_pca), "\n")
print(classification_report(test_y, y_pred_pca))
# Out:
# done in  125.806s
# accuracy: 0.984
#
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99       980
#            1       0.99      0.99      0.99      1135
#            2       0.98      0.98      0.98      1032
#            3       0.98      0.98      0.98      1010
#            4       0.98      0.98      0.98       982
#            5       0.98      0.98      0.98       892
#            6       0.99      0.98      0.99       958
#            7       0.98      0.98      0.98      1028
#            8       0.98      0.98      0.98       974
#            9       0.98      0.97      0.98      1009
#
#     accuracy                           0.98     10000
#    macro avg       0.98      0.98      0.98     10000
# weighted avg       0.98      0.98      0.98     10000

# %% [markdown]
# **When the Principal Component Analysis (PCA) method is applied before the Support Vector Machines (SVM) algorithm, it is generally observed that as the retained variance increases, the classification accuracy will increase, but the execution time will also increase slightly. It also concerns the execution time (training and testing), when SVM is applied with PCA applied beforehand, it will certainly be shorter because PCA will reduce the dimensions, thus resulting in fewer features for each image. This makes image classification easier since fewer dimensions (image features) require less data. Therefore, without the application of the PCA algorithm, the execution of the SVM algorithm requires more time and leads to lower classification accuracy values.**
#
# **More specifically:nFor retained variance = 0.75, we have classification accuracy = 0.9834 and execution time = 47 seconds.
# For retained variance = 0.85, we have classification accuracy = 0.9853 and execution time = 1 minute and 15 seconds.
# For a retained variance of 0.9, we have a classification accuracy of 0.984 and an execution time of 2 minutes and 6 seconds.**
